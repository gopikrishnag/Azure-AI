# %%
print("Good luck Gopi!")
# Out:
# Good luck Gopi!

# %%
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from dotenv import load_dotenv
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
from langchain_groq import ChatGroq
# Out:
# Running cells with '.venv (Python 3.11.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Development/AI/Azure-AI/MCP-Framework/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
# KeyboardInterrupt
